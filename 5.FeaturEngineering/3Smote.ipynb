# %% [markdown]
# SMOTE(synthetic Minority Oversampling Technique)
# technique to handle imbalanced dataset where minority class has significantly fewer instances than the majority class
# smote involves generating synthetic instances of minority class by interpolating between instances
